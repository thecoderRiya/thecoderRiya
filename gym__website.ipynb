# %% [markdown]
# <a href="https://colab.research.google.com/github/thecoderRiya/thecoderRiya/blob/main/gym__website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

# Define the HTML content
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Student Website</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            background-color: #f0f8ff;
            color: #333;
        }

        header {
            background-color: #4CAF50;
            color: white;
            text-align: center;
            padding: 20px;
        }

        nav {
            background-color: #333;
            overflow: hidden;
        }

        nav a {
            float: left;
            display: block;
            color: white;
            padding: 14px 20px;
            text-align: center;
            text-decoration: none;
            width: 25%;
        }

        nav a:hover {
            background-color: #575757;
        }

        section {
            padding: 20px;
            margin: 20px;
            background-color: white;
            border-radius: 8px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
        }

        footer {
            background-color: #333;
            color: white;
            text-align: center;
            padding: 15px;
            position: relative;
            bottom: 0;
            width: 100%;
        }
    </style>
</head>
<body>

<!-- Header Section -->
<header>
    <h1>Welcome to My Student Website</h1>
    <p>Discover more about my courses and contact details.</p>
</header>

<!-- Navigation Bar -->
<nav>
    <a href="#about">About Me</a>
    <a href="#courses">Courses</a>
    <a href="#contact">Contact</a>
</nav>

<!-- About Section -->
<section id="about">
    <h2>About Me</h2>
    <p>Hello! I'm a student passionate about learning new technologies. I specialize in web development, machine learning, and data science.</p>
</section>

<!-- Courses Section -->
<section id="courses">
    <h2>My Courses</h2>
    <ul>
        <li>Web Development 101</li>
        <li>Python for Data Science</li>
        <li>Introduction to Machine Learning</li>
        <li>Advanced Web Development</li>
    </ul>
</section>

<!-- Contact Section -->
<section id="contact">
    <h2>Contact Me</h2>
    <p>Email: student@example.com</p>
    <p>Phone: +1 (555) 123-4567</p>
</section>

<!-- Footer Section -->
<footer>
    <p>&copy; 2024 My Student Website. All Rights Reserved.</p>
</footer>

</body>
</html>
"""

# Display the HTML code in Google Colab
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Student Website</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f0f8ff;
#             color: #333;
#         }
#
#         header {
#             background-color: #4CAF50;
#             color: white;
#             text-align: center;
#             padding: 20px;
#         }
#
#         nav {
#             background-color: #333;
#             overflow: hidden;
#         }
#
#         nav a {
#             float: left;
#             display: block;
#             color: white;
#             padding: 14px 20px;
#             text-align: center;
#             text-decoration: none;
#             width: 25%;
#         }
#
#         nav a:hover {
#             background-color: #575757;
#         }
#
# ...
